# %%
import matplotlib.pyplot as plt

# %%
#multiple points
xpoints = [1,2,3,4,5]
ypoints = [10,20,30,40,50]
plt.plot(xpoints , ypoints)
plt.show()

# %%
#two points
xpoints = [0,6]
ypoints = [0,250]
plt.plot(xpoints , ypoints)
plt.show()

# %%
#default x points .. deadult x values are [0,1,2,3,4,5.......]
ypoints = [10,20,30,40,50,60]
plt.plot( ypoints)
plt.show()

# %%
# format strings fmt    fmt = 'marker|line|color'
# ms is marker size
# mfc is marker face colour

ypoints = [10,20,30,40,50,60]
plt.plot( ypoints, marker = 'v', ms = 15, color = 'g', mfc= 'b')
plt.show()

# %%
""" '-' solid line
':' dotted line
'--' dashed line
'-.' dash-dot line"""
ypoints = [10,20,30,40,50,60]
plt.plot(ypoints , 'o-.k', linewidth='10')
plt.show()

# %%
# multiple lines
x1points = [1,2,3,4,5]
y1points = [10,20,30,40,50]

x2points = [1,2,3,4,5]
y2points = [17,27,38,67,89]

plt.plot(x1points , y1points,'o-.k')
plt.plot(x2points , y2points, '*--b')
plt.show()

# %%
x1points = [1,2,3,4,5]
y1points = [10,20,30,40,50]

x2points = [1,2,3,4,5]
y2points = [17,27,38,67,89]

plt.plot(x1points , y1points, 'o-.k', x2points , y2points,'*--b')

plt.show()

# %%
x1points = [1,2,3,4,5]
y1points = [1,2,3,4,5]

#x2points = [1,2,3,4,5]
#y2points = [17,27,38,67,89]

plt.plot(x1points , y1points, 'o-.k')

plt.show()

# %%
#title & label
xpoints = [1,2,3,4,5]
ypoints = [10,20,30,40,50]
plt.plot(xpoints , ypoints)
plt.xlabel("day")
plt.ylabel("sale")
plt.title("sale per day")
plt.show()

# %%
x1points=[1,2,3,4,5]
y1points=[10,20,30,40,50]
plt.plot(x1points, y1points)
plt.xlabel('Day')
plt.ylabel('Sales')
plt.title('Sales/Day')
plt.show()

# %%
# set font properties for title & Label
# loc means location , 3 values are right , left , center

xpoints = [1,2,3,4,5]
ypoints = [10,20,30,40,50]
plt.plot(xpoints , ypoints)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("sale per day", fontdict = font1, loc = 'right')
plt.xlabel("day" , fontdict= font2 )
plt.ylabel("sale", fontdict= font2)

plt.show()

# %%
# Grid
xpoints = [1,2,3,4,5]
ypoints = [10,20,30,40,50]
plt.plot(xpoints , ypoints)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("sale per day", fontdict = font1, loc = 'right')
plt.xlabel("day" , fontdict= font2 )
plt.ylabel("sale", fontdict= font2)

#plt.grid()
#plt.grid(axis= 'y')
plt.grid(color = 'g' , linestyle = '--' , linewidth = 1 ,axis= 'x')



plt.show()

# %%
# subplots 1st arg is row , 2nd arg is col , 3rd arg is index of the current plot

x1 = [1,2,3,4,5]
y1= [1,2,3,4,5]
#plot 1
plt.subplot(1,2,1)
plt.plot(x1,y1)

#plot 2
x2 = [1,2,3,4,5]
y2 = [17,27,38,67,89]
plt.subplot(1,2,2)
plt.plot(x2,y2)

plt.show()

# %%
# subplots 1st arg is row , 2nd arg is col , 3rd arg is index of the current plot

x1 = [1,2,3,4,5]
y1= [1,2,3,4,5]
#plot 1
plt.subplot(2,1,1)
plt.title("Graph-1")
plt.plot(x1,y1)

#plot 2
x2 = [1,2,3,4,5]
y2 = [17,27,38,67,89]
plt.subplot(2,1,2)
plt.title("Graph-2")
plt.plot(x2,y2)

plt.suptitle("Multiple Plots")

plt.show()

# %%
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 2, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 2, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 2, 6)
plt.plot(x,y)

plt.show()

# %%
# scatter plots

x2 = [1,2,3,4,5]
y2 = [17,27,38,67,89]
sizes = [20,50,100,200,300]
plt.scatter(x2,y2, color = 'hotpink', s=sizes)

x1 = [11,22,33,44,55]
y1 = [37,57,58,87,99]
plt.scatter(x1,y1)

plt.show()

# %%
# Bar plot

x = ['A','B','C','D','E']
y = [10,20,30,40,50]
plt.bar(x,y, width =.1)
plt.show()

# %%
# horizontal Bar plot

x = ['A','B','C','D','E']
y = [10,20,30,40,50]
plt.barh(x,y, color = 'hotpink', height = .1)
plt.show()
